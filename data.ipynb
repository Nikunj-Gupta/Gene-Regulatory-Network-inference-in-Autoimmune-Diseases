# %%
import GEOparse 
import pandas as pd

# %%
# gse = GEOparse.get_GEO(geo="GSE1563", destdir="./")
gse = GEOparse.get_GEO(filepath="./datasets/GSE32591_family.soft.gz")
# gse = GEOparse.get_GEO(filepath="./datasets/soft_files/GSE45291_family.soft.gz")
# Out:
# 19-Jul-2022 23:03:30 INFO GEOparse - Parsing ./datasets/GSE32591_family.soft.gz:
# 19-Jul-2022 23:03:30 DEBUG GEOparse - DATABASE: GeoMiame
# 19-Jul-2022 23:03:30 DEBUG GEOparse - SERIES: GSE32591
# 19-Jul-2022 23:03:30 DEBUG GEOparse - PLATFORM: GPL14663
# 19-Jul-2022 23:03:30 DEBUG GEOparse - SAMPLE: GSM807842
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807843
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807844
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807845
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807846
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807847
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807848
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807849
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807850
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807851
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807852
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807853
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807854
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807855
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807856
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807857
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807858
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807859
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807860
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807861
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807862
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807863
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807864
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807865
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807866
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807867
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807868
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807869
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807870
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807871
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807872
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807873
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807874
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807875
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807876
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807877
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807878
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807879
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807880
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807881
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807882
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807883
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807884
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807885
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807886
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807887
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807888
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807889
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807890
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807891
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807892
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807893
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807894
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807895
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807896
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807897
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807898
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807899
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807900
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807901
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807902
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807903
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807904
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807905
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807906
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807907
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807908
# 19-Jul-2022 23:03:31 DEBUG GEOparse - SAMPLE: GSM807909
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807910
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807911
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807912
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807913
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807914
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807915
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807916
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807917
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807918
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807919
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807920
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807921
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807922
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807923
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807924
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807925
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807926
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807927
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807928
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807929
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807930
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807931
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807932
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807933
# 19-Jul-2022 23:03:32 DEBUG GEOparse - SAMPLE: GSM807934

# %%
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print ("Table data:",)
    print (gsm.table.head())
    print (len(gsm.table['ID_REF'].unique()))
    print(gsm.table.columns)
    break
# Out:
# GSM example:
# Name:  GSM807842
# Metadata:
#  - title : Tub_LN_301
#  - geo_accession : GSM807842
#  - status : Public on Jun 28 2012
#  - submission_date : Oct 04 2011
#  - last_update_date : Jun 28 2012
#  - type : RNA
#  - channel_count : 1
#  - source_name_ch1 : Tubulointerstitium from LN patient
#  - organism_ch1 : Homo sapiens
#  - taxid_ch1 : 9606
#  - characteristics_ch1 : patient number: 1, disease status: LN patient, tissue: Tubulointerstitium from kidney biopsy
#  - molecule_ch1 : total RNA
#  - extract_protocol_ch1 : Total RNA was isolated using the RNeasy mini kit from Qiagen, following the manufacturer’s instructions.
#  - label_ch1 : biotin
#  - label_protocol_ch1 : Biotinylated cRNA were prepared according to the standard Affymetrix protocol from total RNA (Expression Analysis Technical Manual, Affymetrix).
#  - hyb_protocol : standard Affymetrix protocol
#  - scan_protocol : GeneChip arrays were scanned by GeneChip Scanner 3000 7G according to the Affymetrix Expression Analysis Technical Manual.
#  - description : Gene expression data from the tubulointerstitial compartment of human LN kidney
#  - data_processing : The data were analyzed using GenePattern pipeline: RMA method and Human Entrez Gene custom CDF annotation version 10 were used for the normalization.
#  - platform_id : GPL14663
#  - contact_name : Celine,C,Berthier
#  - contact_institute : University of Michigan
#  - contact_address : 1150 W. Medical Center Dr, MSRB2
#  - contact_city : Ann Arbor
#  - contact_state : MI
#  - contact_zip/postal_code : 48109
#  - contact_country : USA
#  - supplementary_file : ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM807nnn/GSM807842/suppl/GSM807842.CEL.gz
#  - series_id : GSE32591, GSE32592
#  - data_row_count : 12029
# Table data:
#   ID_REF     VALUE
# 0      2  8.629684
# 1      9  8.205148
# 2     10  6.379350
# 3     12  6.468665
# 4     13  5.692283
# 12029
# Index(['ID_REF', 'VALUE'], dtype='object')

# %%
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name)
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print("Table data:",)
    print(gpl.table) 
    print(gpl.table.columns)
    break
# Out:
# GPL example:
# Name:  GPL14663
# Metadata:
#  - title : Affymetrix GeneChip Human Genome HG-U133A Custom CDF [Affy_HGU133A_CDF_ENTREZG_10]
#  - geo_accession : GPL14663
#  - status : Public on Feb 01 2012
#  - submission_date : Oct 04 2011
#  - last_update_date : Nov 29 2012
#  - technology : in situ oligonucleotide
#  - distribution : custom-commercial
#  - organism : Homo sapiens
#  - taxid : 9606
#  - manufacturer : Affymetrix
#  - manufacture_protocol : see manufacturer's web site
#  - description : Human Entrez Gene custom CDF annotation version 10
#  - contact_name : Celine,C,Berthier
#  - contact_institute : University of Michigan
#  - contact_address : 1150 W. Medical Center Dr, MSRB2
#  - contact_city : Ann Arbor
#  - contact_state : MI
#  - contact_zip/postal_code : 48109
#  - contact_country : USA
#  - supplementary_file : ftp://ftp.ncbi.nlm.nih.gov/geo/platforms/GPL14nnn/GPL14663/suppl/GPL14663_Hs133A_Hs_ENTREZG.cdf.gz
#  - relation : Alternative to: GPL96 (Alternative CDF [official])
#  - data_row_count : 12029
# Table data:
#                  ID   ORF                                        Gene Symbol  \
# 0                 2   2.0                                                A2M
# 1                 9   9.0                                               NAT1
# 2                10  10.0                                               NAT2
# 3                12  12.0                                           SERPINA3
# 4                13  13.0                                              AADAC
# ...             ...   ...                                                ...
# 12024   AFFX-ThrX-5   NaN  X04603 B subtilis thrC, thrB genes correspondi...
# 12025   AFFX-ThrX-M   NaN  X04603 B subtilis thrC, thrB genes correspondi...
# 12026  AFFX-TrpnX-3   NaN  K01391 B subtilis TrpE protein, TrpD protein, ...
# 12027  AFFX-TrpnX-5   NaN  K01391 B subtilis TrpE protein, TrpD protein, ...
# 12028  AFFX-TrpnX-M   NaN  K01391 B subtilis TrpE protein, TrpD protein, ...
#
#                                              Description         SPOT_ID
# 0                                  alpha-2-macroglobulin             NaN
# 1      N-acetyltransferase1(arylamineN-acetyltransfer...             NaN
# 2      N-acetyltransferase2(arylamineN-acetyltransfer...             NaN
# 3      serpinpeptidaseinhibitor,cladeA(alpha-1antipro...             NaN
# 4                     arylacetamidedeacetylase(esterase)             NaN
# ...                                                  ...             ...
# 12024                          Poly-A Affymetrix control   --AFFX-ThrX-5
# 12025                          Poly-A Affymetrix control   --AFFX-ThrX-M
# 12026                          Poly-A Affymetrix control  --AFFX-TrpnX-3
# 12027                          Poly-A Affymetrix control  --AFFX-TrpnX-5
# 12028                          Poly-A Affymetrix control  --AFFX-TrpnX-M
#
# [12029 rows x 5 columns]
# Index(['ID', 'ORF', 'Gene Symbol', 'Description', 'SPOT_ID'], dtype='object')

# %%
for gpl_name, gpl in gse.gpls.items(): 
#     print('ELF1' in gpl.table['Gene Symbol'].unique()) 
    print(gpl.table[gpl.table['Gene Symbol']=='ELF1'])
    break

# %%
# df_tag = False 
# for gsm_name, gsm in gse.gsms.items():
#     # df = gsm.table 
#     # print(df[df['ID_REF'].str.contains('9145', regex=False)]) 
#     if not df_tag: 
#         df = gsm.table 
#         df_tag = True 
#     else: 
#         df = pd.merge(df, gsm.table, on='ID_REF') 
#     # break 
# print(df)

# %%
# import cdflib 
# cdf_file = cdflib.CDF('./datasets/GSE32591_RAW/GPL14663_Hs133A_Hs_ENTREZG.cdf')
# print(cdf_file.cdf_info())
