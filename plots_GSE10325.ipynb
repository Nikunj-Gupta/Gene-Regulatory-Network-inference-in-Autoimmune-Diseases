# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
raw_expre = pd.read_csv('datasets/GSE10325/GSE10325/raw_expre.csv', sep=",")  
raw_expre
# Out:
#             Unnamed: 0  GSM260886  GSM260887  GSM260888  GSM260889  GSM260890  \
# 0            1007_s_at      241.9      341.9      165.5      245.0      443.6
# 1              1053_at       71.5      155.3       72.5      127.3      151.5
# 2               117_at       81.7      196.5      343.6       72.1       96.2
# 3               121_at      704.8      511.2      792.3      701.2      580.9
# 4            1255_g_at       31.3       16.2       51.9       25.2       39.6
# ...                ...        ...        ...        ...        ...        ...
# 22278   AFFX-ThrX-5_at        6.8        7.9       30.8        6.6        6.2
# 22279   AFFX-ThrX-M_at        4.2       29.5       29.2        6.2       16.7
# 22280  AFFX-TrpnX-3_at        1.9        2.7        7.8        2.5        5.8
# 22281  AFFX-TrpnX-5_at       11.7        3.7       10.8        6.0       12.1
# 22282  AFFX-TrpnX-M_at        2.9        4.5        3.1        4.0        4.0
#
#        GSM260891  GSM260892  GSM260893  GSM260894  ...  GSM260943  GSM260944  \
# 0          207.5      508.5      165.0      268.4  ...      166.1      223.6
# 1          117.2      214.9      174.6       55.8  ...      199.8      156.9
# 2           50.7      143.9      305.3       78.1  ...       88.8     1335.4
# 3          637.2     1056.1      552.0      541.9  ...      598.4      640.4
# 4           29.5       48.3       36.5       40.8  ...       39.5       38.0
# ...          ...        ...        ...        ...  ...        ...        ...
# 22278       15.8       13.3        7.2        8.2  ...        3.6       11.5
# 22279       27.5       35.5       22.8        5.5  ...       38.6       18.4
# 22280        6.3       17.1        2.9        2.5  ...        2.8        3.4
# 22281        7.4       10.3        7.7        3.3  ...       10.3       27.7
# 22282        2.2       15.0        5.2        4.2  ...        2.0        7.1
#
#        GSM260945  GSM260946  GSM260947  GSM260948  GSM260949  GSM260950  \
# 0          135.2      220.3      109.5      276.4      317.4      204.2
# 1           71.1      169.8      108.5       93.5      185.0       82.7
# 2           40.0       59.6      299.1       53.5      120.9       51.9
# 3          315.1      387.1      419.3      529.1      664.5      617.6
# 4           15.8       18.3       25.9       55.1       38.0       35.1
# ...          ...        ...        ...        ...        ...        ...
# 22278        3.9        2.2        3.3        5.4        5.2        5.2
# 22279        9.9       12.4        8.9        6.4       23.3        4.5
# 22280        7.8        1.6       14.6        2.5        6.0        1.2
# 22281        6.9       11.0        2.2        5.4        5.2        5.1
# 22282        1.3        1.7        2.2        2.0        4.1        3.2
#
#        GSM260951  GSM260952
# 0          165.4      139.9
# 1          179.2       74.6
# 2          125.4      447.8
# 3          395.6      426.9
# 4            2.7       31.3
# ...          ...        ...
# 22278       16.0        6.3
# 22279       10.7       16.5
# 22280        2.3        2.0
# 22281        7.2        4.5
# 22282        3.7        3.4
#
# [22283 rows x 68 columns]

# %%
# list(raw_expre['Unnamed: 0'])

# %%
# identifiers = ['204287_at'] 
# for i in identifiers: 
#     if i in list(raw_expre['Unnamed: 0']): 
#         print("Yes: ", i) 
#         break

# %%
# pheno = pd.read_csv('datasets/GSE10325/GSE10325/pheno.csv', sep=",")  
# pheno

# %%
"""
Filter only SLE patients 
"""

pheno = pd.read_csv('datasets/GSE10325/GSE10325/pheno.csv', sep=",")  
sle = list(pheno[pheno['title'].str.contains('SLE')]['geo_accession']) 
sle.append('Unnamed: 0')
raw_expre = raw_expre[sle] 
raw_expre
# Out:
#        GSM260914  GSM260915  GSM260916  GSM260917  GSM260918  GSM260919  \
# 0          284.8      427.4      387.3      236.4      109.4      213.6
# 1           63.7      151.4       73.1      153.2      162.7      116.1
# 2           48.6      114.9      104.1      118.3      379.6       50.7
# 3          652.2      604.3     1082.4      472.2      414.9      463.9
# 4           38.4       46.4       63.2       28.3       26.1       26.5
# ...          ...        ...        ...        ...        ...        ...
# 22278        8.0        8.8       11.1        3.9        4.1        5.5
# 22279        8.3        9.8       12.7        5.1        5.4       26.2
# 22280        2.7        3.7       16.3        2.7       11.3       17.7
# 22281        6.8        3.5       12.1        4.9        4.4       15.5
# 22282        4.4        2.8        5.5        1.1        4.0        3.0
#
#        GSM260920  GSM260921  GSM260922  GSM260923  ...  GSM260944  GSM260945  \
# 0          250.4      132.4      279.5      335.3  ...      223.6      135.2
# 1          117.3      125.6      107.3      307.9  ...      156.9       71.1
# 2          128.5      675.1      106.5       94.9  ...     1335.4       40.0
# 3          480.0      559.2      960.4      655.8  ...      640.4      315.1
# 4           32.3       29.9       31.8       36.9  ...       38.0       15.8
# ...          ...        ...        ...        ...  ...        ...        ...
# 22278        6.2        4.0       31.7       52.1  ...       11.5        3.9
# 22279        6.2       21.7        4.7       17.7  ...       18.4        9.9
# 22280        5.1       14.6        3.5        2.2  ...        3.4        7.8
# 22281        5.0       17.4       19.4        7.2  ...       27.7        6.9
# 22282        4.2        4.6        6.1        3.4  ...        7.1        1.3
#
#        GSM260946  GSM260947  GSM260948  GSM260949  GSM260950  GSM260951  \
# 0          220.3      109.5      276.4      317.4      204.2      165.4
# 1          169.8      108.5       93.5      185.0       82.7      179.2
# 2           59.6      299.1       53.5      120.9       51.9      125.4
# 3          387.1      419.3      529.1      664.5      617.6      395.6
# 4           18.3       25.9       55.1       38.0       35.1        2.7
# ...          ...        ...        ...        ...        ...        ...
# 22278        2.2        3.3        5.4        5.2        5.2       16.0
# 22279       12.4        8.9        6.4       23.3        4.5       10.7
# 22280        1.6       14.6        2.5        6.0        1.2        2.3
# 22281       11.0        2.2        5.4        5.2        5.1        7.2
# 22282        1.7        2.2        2.0        4.1        3.2        3.7
#
#        GSM260952       Unnamed: 0
# 0          139.9        1007_s_at
# 1           74.6          1053_at
# 2          447.8           117_at
# 3          426.9           121_at
# 4           31.3        1255_g_at
# ...          ...              ...
# 22278        6.3   AFFX-ThrX-5_at
# 22279       16.5   AFFX-ThrX-M_at
# 22280        2.0  AFFX-TrpnX-3_at
# 22281        4.5  AFFX-TrpnX-5_at
# 22282        3.4  AFFX-TrpnX-M_at
#
# [22283 rows x 40 columns]

# %%
"""
Mapping IDs for ELF1 / IRF1 / SYNGR1  
"""

id_refs = {'GSE121239_family.soft.gz': 
           {'ELF1': ['212420_at'],
            'IRF1': ['202531_at'], 
            'SYNGR1': ['204287_at'] 
           }
          } 
elf1 = id_refs['GSE121239_family.soft.gz']['ELF1'][0] 
irf1 = id_refs['GSE121239_family.soft.gz']['IRF1'][0] 
syngr1 = id_refs['GSE121239_family.soft.gz']['SYNGR1'][0]

# %% [markdown]
# ## Gene Plots (for ELF1 / IRF1 / SYNGR1)

# %%
"""
ELF1 
""" 

df = raw_expre[raw_expre['Unnamed: 0']==elf1].T.drop(['Unnamed: 0']) 
df['Sample_number'] = range(1, len(df) + 1)
df.plot.scatter(x='Sample_number', y=df.columns[0], ylim=(0, 1200), ylabel='ELF1') 
print(df.columns[0])
# Out:
# 11804

# %%
"""
IRF1 
""" 

df = raw_expre[raw_expre['Unnamed: 0']==irf1].T.drop(['Unnamed: 0']) 
df['Sample_number'] = range(1, len(df) + 1)
df.plot.scatter(x='Sample_number', y=df.columns[0], ylim=(0, 6200), ylabel='IRF1') 
print(df.columns[0])
# Out:
# 2058

# %%
"""
SYNGR1 
""" 

df = raw_expre[raw_expre['Unnamed: 0']==syngr1].T.drop(['Unnamed: 0']) 
df['Sample_number'] = range(1, len(df) + 1)
df.plot.scatter(x='Sample_number', y=df.columns[0], ylim=(0, 500), ylabel='SYNGR1') 
print(df.columns[0])
# Out:
# 3813

# %%
""" 
Box plot 
"""

df = raw_expre[(raw_expre['Unnamed: 0']==syngr1) | (raw_expre['Unnamed: 0']==elf1) | (raw_expre['Unnamed: 0']==irf1)] 
df = df.T.drop(['Unnamed: 0']) 
df=df.astype(float) 

df.boxplot(column=(list(df.columns))).set_xticklabels(['IRF1', 'SYNGR1', 'ELF1']) 
print(list(df.columns))
# Out:
# [2058, 3813, 11804]

# %% [markdown]
# ## Distribution of Data
#
# #### Means of genes vs number of genes with that mean. Or a histogram of means of genes for all samples.

# %%
raw_expre.T.drop(['Unnamed: 0']).T.mean().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Coefficient of variation Plot

# %%
cv = lambda x: np.std(x, ddof=1) / np.mean(x) 
raw_expre['CV'] = raw_expre.apply(lambda row : cv(row.T.drop(['Unnamed: 0'])), axis = 1)
# Out:
# /var/folders/_1/dc2yd0kn325bph09grgy33lr0000gn/T/ipykernel_51299/330539545.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_expre['CV'] = raw_expre.apply(lambda row : cv(row.T.drop(['Unnamed: 0'])), axis = 1)

# %%
raw_expre['CV'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Min coefficient of variation

# %%
raw_expre['CV'].min()
# Out:
# 0.17999726219435816

# %% [markdown]
# #### Max coefficient of variation

# %%
raw_expre['CV'].max()
# Out:
# 6.054594146827342

# %% [markdown]
# #### Coefficient of variation less than 1

# %%
raw_expre[raw_expre['CV']<0.5]
# Out:
#        GSM260914  GSM260915  GSM260916  GSM260917  GSM260918  GSM260919  \
# 0          284.8      427.4      387.3      236.4      109.4      213.6
# 1           63.7      151.4       73.1      153.2      162.7      116.1
# 3          652.2      604.3     1082.4      472.2      414.9      463.9
# 4           38.4       46.4       63.2       28.3       26.1       26.5
# 5          725.4     1036.0      671.6      668.0      679.6     1297.9
# ...          ...        ...        ...        ...        ...        ...
# 22230    11929.7    17914.4    16674.6    19628.2    17339.2    15482.5
# 22231     5131.5     4486.1     4275.5     6955.6     9698.4     5999.8
# 22233     4304.4     3305.1     3539.2     6705.0     9864.2     4036.8
# 22253       41.7       51.2       65.8       47.7       50.8       59.0
# 22260       71.0       44.3       56.6       22.2       36.4       37.1
#
#        GSM260920  GSM260921  GSM260922  GSM260923  ...  GSM260945  GSM260946  \
# 0          250.4      132.4      279.5      335.3  ...      135.2      220.3
# 1          117.3      125.6      107.3      307.9  ...       71.1      169.8
# 3          480.0      559.2      960.4      655.8  ...      315.1      387.1
# 4           32.3       29.9       31.8       36.9  ...       15.8       18.3
# 5         1301.0      959.3      877.4     1351.9  ...      830.0      691.0
# ...          ...        ...        ...        ...  ...        ...        ...
# 22230    14001.6    21075.7    19278.7    20605.5  ...    12695.9    14711.8
# 22231     3672.3     9850.6    12553.6    12497.2  ...     3844.9     4910.0
# 22233     1669.1     7920.5    12563.6    11217.1  ...     2773.9     5138.0
# 22253       45.8       34.9       71.4       49.4  ...       27.4       25.1
# 22260       64.0       49.9      101.2       56.7  ...       32.2       37.4
#
#        GSM260947  GSM260948  GSM260949  GSM260950  GSM260951  GSM260952  \
# 0          109.5      276.4      317.4      204.2      165.4      139.9
# 1          108.5       93.5      185.0       82.7      179.2       74.6
# 3          419.3      529.1      664.5      617.6      395.6      426.9
# 4           25.9       55.1       38.0       35.1        2.7       31.3
# 5          495.8     1357.0     1329.6      767.5      555.9      872.4
# ...          ...        ...        ...        ...        ...        ...
# 22230    11156.9    13982.7    18798.5    11715.4    11751.6     9966.5
# 22231     6381.3     6877.0     5669.1     4531.7     7882.1     7220.0
# 22233     6368.3     4134.7     4657.7     4186.7     8087.4     6909.4
# 22253       15.1       42.7       39.5       30.7       19.0       21.3
# 22260       33.0       88.3       61.1       35.5       34.9       66.3
#
#                       Unnamed: 0        CV
# 0                      1007_s_at  0.370839
# 1                        1053_at  0.417863
# 3                         121_at  0.321223
# 4                      1255_g_at  0.416820
# 5                        1294_at  0.412740
# ...                          ...       ...
# 22230            AFFX-hum_alu_at  0.458054
# 22231  AFFX-HUMGAPDH/M33197_3_at  0.479161
# 22233  AFFX-HUMGAPDH/M33197_M_at  0.498022
# 22253        AFFX-r2-Bs-lys-3_at  0.442630
# 22260      AFFX-r2-Bs-thr-5_s_at  0.380429
#
# [8802 rows x 41 columns]

# %% [markdown]
# #### Coefficient of variation of ELF1 / IRF1 / SYNGR1

# %%
raw_expre[raw_expre['Unnamed: 0']==elf1]['CV']
# Out:
# 11804    0.530082
# Name: CV, dtype: float64

# %%
raw_expre[raw_expre['Unnamed: 0']==irf1]['CV']
# Out:
# 2058    0.786998
# Name: CV, dtype: float64

# %%
raw_expre[raw_expre['Unnamed: 0']==syngr1]['CV']
# Out:
# 3813    0.666321
# Name: CV, dtype: float64
